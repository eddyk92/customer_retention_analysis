# %%
import sys, os
sys.path.append("../scripts")

from data_pull import load_data

df = load_data("local", "../sql/retention_queries.sql")
df.head()
# Out:
#    order_id  user_id               order_date first_name  last_name gender  \
# 0    122333    97994  2025-10-30 23:58:05 UTC        Lee      Beard      M
# 1     77369    61959  2025-10-30 23:55:44 UTC      Linda   Robinson      F
# 2     44855    35791  2025-10-30 23:50:56 UTC       Adam  Rodriguez      M
# 3     13326    10717  2025-10-30 23:43:43 UTC  Christina   Castillo      F
# 4    104236    83468  2025-10-30 23:42:24 UTC     Dwayne    Johnson      M
#
#   country  total_sale
# 0  Brasil       49.99
# 1   China       49.99
# 2   China      187.00
# 3  Brasil       67.56
# 4   China       39.45
